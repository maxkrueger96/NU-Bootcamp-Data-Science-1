# %%
import os
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
import scipy.stats as st

# %%
file = "country_case_df.csv"


# Read df into pandas.
country_case_df = pd.read_csv(file)
country_case_df.head()
# Out:
#    Unnamed: 0      country  confirmed  deaths  population  sq_km_area  \
# 0           0  Afghanistan     148572    6804    35530081    652090.0
# 1           1      Albania     133211    2457     2930187     28748.0
# 2           2      Algeria     175229    4370    41318142   2381741.0
# 3           3      Andorra      14766     128       76965       468.0
# 4           4       Angola      43070    1022    29784193   1246700.0
#
#    life_expectancy elevation_in_meters continent abbreviation  \
# 0             45.9                 NaN      Asia           AF
# 1             71.6                 NaN    Europe           AL
# 2             69.7                 800    Africa           DZ
# 3             83.5               1,996    Europe           AD
# 4             38.3               1,112    Africa           AO
#
#                     location   iso      capital_city  percentage_confirmed_%  \
# 0  Southern and Central Asia   4.0             Kabul                0.418158
# 1            Southern Europe   8.0            Tirana                4.546160
# 2            Northern Africa  12.0             Alger                0.424097
# 3            Southern Europe  20.0  Andorra la Vella               19.185344
# 4             Central Africa  24.0            Luanda                0.144607
#
#    percentage_deaths_%
# 0             0.019150
# 1             0.083851
# 2             0.010576
# 3             0.166309
# 4             0.003431

# %%
happiness_2021_file = "WHR2021_Data.csv"

#Read df into pandas 
happiness_2021_df = pd.read_csv(happiness_2021_file)
happiness_2021_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# 3                 10.878           0.983                     73.0
# 4                 10.932           0.942                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# 2                         0.919       0.025                      0.292
# 3                         0.955       0.160                      0.673
# 4                         0.913       0.175                      0.338
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
# 1                      2.43                             1.502
# 2                      2.43                             1.566
# 3                      2.43                             1.482
# 4                      2.43                             1.501
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
# 1                         1.108                                  0.763
# 2                         1.079                                  0.816
# 3                         1.172                                  0.772
# 4                         1.079                                  0.753
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798

# %%
country_case_df.rename(columns={"country":"Country name", "deaths":"Deaths", "life_expectancy":"Healthy life expectancy"}, inplace=True)

# %%
country_case_df.head()
# Out:
#    Unnamed: 0 Country name  confirmed  Deaths  population  sq_km_area  \
# 0           0  Afghanistan     148572    6804    35530081    652090.0
# 1           1      Albania     133211    2457     2930187     28748.0
# 2           2      Algeria     175229    4370    41318142   2381741.0
# 3           3      Andorra      14766     128       76965       468.0
# 4           4       Angola      43070    1022    29784193   1246700.0
#
#    Healthy life expectancy elevation_in_meters continent abbreviation  \
# 0                     45.9                 NaN      Asia           AF
# 1                     71.6                 NaN    Europe           AL
# 2                     69.7                 800    Africa           DZ
# 3                     83.5               1,996    Europe           AD
# 4                     38.3               1,112    Africa           AO
#
#                     location   iso      capital_city  percentage_confirmed_%  \
# 0  Southern and Central Asia   4.0             Kabul                0.418158
# 1            Southern Europe   8.0            Tirana                4.546160
# 2            Northern Africa  12.0             Alger                0.424097
# 3            Southern Europe  20.0  Andorra la Vella               19.185344
# 4             Central Africa  24.0            Luanda                0.144607
#
#    percentage_deaths_%
# 0             0.019150
# 1             0.083851
# 2             0.010576
# 3             0.166309
# 4             0.003431

# %%
Together_merge_2021_df = pd.merge(happiness_2021_df, country_case_df, on="Country name", how="outer")
Together_merge_2021_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy_x  \
# 0                 10.775           0.954                       72.0
# 1                 10.933           0.954                       72.7
# 2                 11.117           0.942                       74.4
# 3                 10.878           0.983                       73.0
# 4                 10.932           0.942                       72.4
#
#    Freedom to make life choices  ...  sq_km_area  Healthy life expectancy_y  \
# 0                         0.949  ...    338145.0                       77.4
# 1                         0.946  ...     43094.0                       76.5
# 2                         0.919  ...     41284.0                       79.6
# 3                         0.955  ...    103000.0                       79.4
# 4                         0.913  ...     41526.0                       78.3
#
#    elevation_in_meters  continent  abbreviation          location    iso  \
# 0                  164     Europe            FI  Nordic Countries  246.0
# 1                   34     Europe            DK  Nordic Countries  208.0
# 2                1,350     Europe            CH    Western Europe  756.0
# 3                  557     Europe            IS  Nordic Countries  352.0
# 4                   30     Europe            NL    Western Europe  528.0
#
#              capital_city  percentage_confirmed_%  percentage_deaths_%
# 0  Helsinki [Helsingfors]                1.961859             0.017816
# 1              Copenhagen                5.588369             0.044510
# 2                    Bern                8.503334             0.128669
# 3                 Reykjav                2.457429             0.008955
# 4               Amsterdam               11.166165             0.106369
#
# [5 rows x 34 columns]

# %%
Together_merge_2021_df.dtypes
# Out:
# Country name                                   object
# Regional indicator                             object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy_x                     float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# Dystopia + residual                           float64
# Unnamed: 0                                    float64
# confirmed                                     float64
# Deaths                                        float64
# population                                    float64
# sq_km_area                                    float64
# Healthy life expectancy_y                     float64
# elevation_in_meters                            object
# continent                                      object
# abbreviation                                   object
# location                                       object
# iso                                           float64
# capital_city                                   object
# percentage_confirmed_%                        float64
# percentage_deaths_%                           float64
# dtype: object

# %%
condensed_question_11_df = Together_merge_2021_df.groupby(["Country name","Logged GDP per capita"]).sum()[["Deaths"]]
condensed_question_11_df.head()
# Out:
#                                       Deaths
# Country name Logged GDP per capita
# Afghanistan  7.695                    6804.0
# Albania      9.520                    2457.0
# Algeria      9.342                    4370.0
# Argentina    9.962                  106447.0
# Armenia      9.487                    4621.0

# %%
Together_merge_2021_df.dropna(inplace=True)

# %%
plt.rcParams['figure.figsize'] = [8, 8]
x_values = Together_merge_2021_df['Logged GDP per capita']
y_values = np.log(Together_merge_2021_df['Deaths'])
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values=x_values*slope + intercept
line_eq_1 = "y= " + str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq_1,(7,2),fontsize =8, color='red')
plt.xlabel('(Logged GDP per capita)')
plt.ylabel('log(Deaths)')
plt.title('Logged Deaths versus Logged GDP per capita')
print(f'The r-squared is: {rvalue ** 2}')
plt.show()
# Out:
# The r-squared is: 0.17877748319954978

# %%
happiness_2020_file = "WHR2020_Data.csv"

#Read df into pandas 
happiness_2020_df = pd.read_csv(happiness_2020_file)
happiness_2020_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# 3              10.772559        0.974670                73.000000
# 4              11.087804        0.952487                73.200783
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
# 1                      0.951444    0.066202                   0.168489
# 2                      0.921337    0.105911                   0.303728
# 3                      0.948892    0.246944                   0.711710
# 4                      0.955750    0.134533                   0.263218
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                          1.285190
# 1                  1.972317                          1.326949
# 2                  1.972317                          1.390774
# 3                  1.972317                          1.326502
# 4                  1.972317                          1.424207
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
# 1                      1.503449                               0.979333
# 2                      1.472403                               1.040533
# 3                      1.547567                               1.000843
# 4                      1.495173                               1.008072
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                  0.159670
# 1                                    0.665040                  0.242793
# 2                                    0.628954                  0.269056
# 3                                    0.661981                  0.362330
# 4                                    0.670201                  0.287985
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                 0.477857             2.762835
# 1                                 0.495260             2.432741
# 2                                 0.407946             2.350267
# 3                                 0.144541             2.460688
# 4                                 0.434101             2.168266

# %%
Together_merge_2020_With_countries_df = pd.merge(happiness_2020_df, country_case_df, on="Country name", how="outer")
Together_merge_2020_With_countries_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy_x  \
# 0              10.639267        0.954330                  71.900825
# 1              10.774001        0.955991                  72.402504
# 2              10.979933        0.942847                  74.102448
# 3              10.772559        0.974670                  73.000000
# 4              11.087804        0.952487                  73.200783
#
#    Freedom to make life choices  ...  sq_km_area  Healthy life expectancy_y  \
# 0                      0.949172  ...    338145.0                       77.4
# 1                      0.951444  ...     43094.0                       76.5
# 2                      0.921337  ...     41284.0                       79.6
# 3                      0.948892  ...    103000.0                       79.4
# 4                      0.955750  ...    323877.0                       78.7
#
#    elevation_in_meters  continent  abbreviation          location    iso  \
# 0                  164     Europe            FI  Nordic Countries  246.0
# 1                   34     Europe            DK  Nordic Countries  208.0
# 2                1,350     Europe            CH    Western Europe  756.0
# 3                  557     Europe            IS  Nordic Countries  352.0
# 4                  460     Europe            NO  Nordic Countries  578.0
#
#              capital_city  percentage_confirmed_%  percentage_deaths_%
# 0  Helsinki [Helsingfors]                1.961859             0.017816
# 1              Copenhagen                5.588369             0.044510
# 2                    Bern                8.503334             0.128669
# 3                 Reykjav                2.457429             0.008955
# 4                    Oslo                2.615080             0.015060
#
# [5 rows x 34 columns]

# %%
condensed_question_11_2020_df = Together_merge_2020_With_countries_df.groupby(["Country name","Logged GDP per capita"]).sum()[["Deaths"]]
condensed_question_11_2020_df.head()
# Out:
#                                       Deaths
# Country name Logged GDP per capita
# Afghanistan  7.462861                 6804.0
# Albania      9.417931                 2457.0
# Algeria      9.537965                 4370.0
# Argentina    9.810955               106447.0
# Armenia      9.100476                 4621.0

# %%
Together_merge_2020_With_countries_df.dtypes
# Out:
# Country name                                   object
# Regional indicator                             object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy_x                     float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# Dystopia + residual                           float64
# Unnamed: 0                                    float64
# confirmed                                     float64
# Deaths                                        float64
# population                                    float64
# sq_km_area                                    float64
# Healthy life expectancy_y                     float64
# elevation_in_meters                            object
# continent                                      object
# abbreviation                                   object
# location                                       object
# iso                                           float64
# capital_city                                   object
# percentage_confirmed_%                        float64
# percentage_deaths_%                           float64
# dtype: object

# %%
Together_merge_2020_With_countries_df.dropna(inplace=True)

# %%
plt.rcParams['figure.figsize'] = [8, 8]
x_values = Together_merge_2020_With_countries_df['Logged GDP per capita']
y_values = np.log(Together_merge_2020_With_countries_df['Deaths'])
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values=x_values*slope + intercept
line_eq_1 = "y= " + str(round(slope,2)) + "x + "+ str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq_1,(7,2),fontsize =8, color='red')
plt.xlabel('(Logged GDP per capita)')
plt.ylabel('log(Deaths)')
plt.title('Logged Deaths versus Logged GDP per capita')
print(f'The r-squared is: {rvalue ** 2}')
plt.show()
# Out:
# The r-squared is: 0.19750938461266582
